# %% [markdown]
# # Econ 251 Coding 2 (For Submission)

# %% [markdown]
# # 1. Load and Install Packages & Connect to Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# import 
import numpy as np # numpy 
import pandas as pd # pandas
import matplotlib.pyplot as plt # matplotlib
from google.colab import drive # save your work on Google drive
import os # useful when change working directory

# %%
# mounting to Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# check list of your current dirtory
os.listdir()
# Out:
# ['.config', 'drive', 'sample_data']

# %%
# change your working dirtory
os.chdir('/content/drive/MyDrive/Colab Notebooks')

# %%
! pip install wooldridge # install package wooldridge 
import wooldridge as woo

import statsmodels.formula.api as smf # import package statsmodels for regression model
import statsmodels.api as sm # create other analysis in statsmodels
# Out:
# ...
#      |████████████████████████████████| 5.1 MB 5.2 MB/s
# ...
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # 2. Run Regression Model
#
# Population Regressio Model:
#
# $log(wage) = \beta_0 + \beta_1 exper + \beta_2 IQ +u$

# %% [markdown]
# ## 2.1 Load Data

# %%
wage2 = woo.dataWoo('wage2') # import data ceosal1 from woo
wage2.columns
# Out:
# Index(['wage', 'hours', 'IQ', 'KWW', 'educ', 'exper', 'tenure', 'age',
#        'married', 'black', 'south', 'urban', 'sibs', 'brthord', 'meduc',
#        'feduc', 'lwage'],
#       dtype='object')

# %% [markdown]
# ## 2.2. Descriptive Statistics

# %%
wage2.describe() # get descritive statistics

# %%
wage2[['log_lwage', 'log_wage']].cov() # check correlation between wage  and lwage variables

# %% [markdown]
# ## 2.3. Run a regression model and Report the results

# %% [markdown]
# ## 2.4. Create exper2 as follows:

# %%
# create exper2 
from numpy import random
len(wage2)
wage2['exper2'] = wage2['exper']+ random.rand(935)

# %% [markdown]
# ## 2.5 Run the regression model with *exper2* and Compare the regression model in 2.3
#
# $log(wage) = \beta_0 + \beta_1 exper + \beta_2 exper2 + \beta_3 IQ +u$

# %%
import statsmodels.formula.api as smf # import package statsmodels for regression model
import statsmodels.api as sm # create other analysis in statsmodels

# %%
ols_gpa = smf.ols('exper ~ exper2 + IQ', data = gpa1)
result5 = ols_gpa.fit()
print(result5.summary())

# %%
table0=sm.stats.anova_lm(results, type=2) # create a table with SSE and SSR
print(table0)

# %%
ols_wage2 = smf.ols(formula='exper ~ exper2 ', data=wage1)
result4= ols_wage2.fit()
print(result4.summary())

# %% [markdown]
# ## 2.6 Run the regression model without IQ and Compare the regression model in 2.3
#
# $log(wage) = \beta_0 + \beta_1 exper +u$

# %%
gpa1 = woo.data("wage2") # load data 
gpa1

# %%
reg = smf.ols(formula='log_exper ~ log_exper2', data=ceosal1)
results = reg.fit() # regression results
print(results.summary())
